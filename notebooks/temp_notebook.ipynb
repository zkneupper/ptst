# %% [markdown]
# https://unsplash.com/collections/5003245/allegra-searle-lebel

# %%
import ptst

# %%
[x for x in dir(ptst) if not x.startswith('_')]
# Out:
# ['ContentLoss',
#  'Normalization',
#  'StyleLoss',
#  'StyleTransferer',
#  'gram_matrix',
#  'image_loader',
#  'imshow',
#  'load_images',
#  'stobject',
#  'styletransfer']

# %%
st = ptst.StyleTransferer()

# %%
assert st.__str__() == 'StyleTransferer'

# %%
[x for x in dir(st) if not x.startswith('_')]
# Out:
# ['content_img', 'device', 'set_content_img', 'style_img']

# %% [markdown]
# # Load images

# %%
lion_img_path = './data/hand_processed/images/lion_matthew-kerslake1.jpg'
space_img_path = './data/hand_processed/images/space_jeremy-thomas3.jpg'

# %%
st.set_content_img(lion_img_path)

# %%
ptst.imshow(st.style_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-8167f0ce5c58> in <module>
# ----> 1 ptst.imshow(st.style_img)
#
# ~/Git/pytorch-style-transfer/ptst/src/ptst/load_images.py in imshow(tensor, title)
#      24
#      25 def imshow(tensor, title=None):
# ---> 26     """
#      27     # MAKE figsize AN OPTIONAL ARTUMENT
#      28     # E.G. imshow(tensor, title=None, figsize=(10,10))
#
# AttributeError: 'NoneType' object has no attribute 'cpu'

# %%
ptst.imshow(st.content_img)

# %%
space_img = ptst.image_loader(space_img_path, imsize=512, device=device)

# %%
'StyleTransferer'

# %%
str(type(st)) == 'ptst.stobject.StyleTransferer'

# %%
print(st)

# %%
print(st.content_img)
print(st.style_img)

# %%
# dir(st.device.type)

# %%
# dir(st.__class__())

# %%
import torch
# import matplotlib.pyplot as plt

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import ptst

# %%
[x for x in dir(ptst) if not x.startswith('_')]

# %%
lion_img_path = './data/hand_processed/images/lion_matthew-kerslake1.jpg'
lion_img_path

# %%
lion_img = ptst.image_loader(lion_img_path, imsize=512, device=device)

# %%
space_img_path = './data/hand_processed/images/space_jeremy-thomas3.jpg'
space_img_path

# %%
space_img = ptst.image_loader(space_img_path, imsize=512, device=device)

# %%
# plt.figure()
# plt.figure(figsize=(20,20))
ptst.imshow(lion_img, title='Lion Image')

# %%
# plt.figure()
# plt.figure(figsize=(20,20))
ptst.imshow(space_img, title='Lion Image')

# %%
# assert style_img.size() == content_img.size(), \
#     "we need to import style and content images of the same size"
assert space_img.size() == lion_img.size(), \
    "we need to import style and content images of the same size"

# %%
print(space_img.size())
print(lion_img.size())

# %%
# import matplotlib.pyplot as plt

# %%
# # plt.figure()
# plt.figure(figsize=(20,20))
# ptst.imshow(lion_img, title='Lion Image')

# %%
# lion_img = image_loader(lion_img_path, imsize=512, device=device)

# %%
import torch
import torchvision.transforms as transforms
# from PIL import Image

# %%
unloader = transforms.ToPILImage()  # reconvert into PIL image

plt.ion()

def imshow(tensor, title=None):
    image = tensor.cpu().clone()  # we clone the tensor to not do changes on it
    image = image.squeeze(0)      # remove the fake batch dimension
    image = unloader(image)
    plt.imshow(image)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated


plt.figure()
# plt.figure(figsize=(20,20))
imshow(lion_img, title='Lion Image')

# %%
import torchvision.transforms as transforms
from PIL import Image
import torch

def image_loader(image_file_path, imsize=512, device=device):
    """
    # desired size of the output image
    imsize = 512 # int(128 * 4)
    """
    loader = transforms.Compose([
        transforms.Resize(imsize),  # scale imported image
        transforms.ToTensor()])  # transform it into a torch tensor    
    
    image = Image.open(image_file_path)
    # fake batch dimension required to fit network's input dimensions
    image = loader(image).unsqueeze(0)
    return image.to(device, torch.float)

# %%
lion_img_path = './data/hand_processed/images/lion_matthew-kerslake1.jpg'
lion_img_path

# %%
lion_img = image_loader(lion_img_path, imsize=512, device=device)

# %%
unloader = transforms.ToPILImage()  # reconvert into PIL image

plt.ion()

def imshow(tensor, title=None):
    image = tensor.cpu().clone()  # we clone the tensor to not do changes on it
    image = image.squeeze(0)      # remove the fake batch dimension
    image = unloader(image)
    plt.imshow(image)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated


plt.figure()
# plt.figure(figsize=(20,20))
imshow(lion_img, title='Lion Image')

# %%
s_h = 3474
s_l = 5257
l_h = 1982
l_l = 2973

# %%
s_h / (s_l -46)

# %%
(s_l -46)

# %%
l_h / l_l

# %%
# desired size of the output image
imsize = 512 # int(128 * 4)

loader = transforms.Compose([
    transforms.Resize(imsize),  # scale imported image
    transforms.ToTensor()])  # transform it into a torch tensor

def image_loader(image_name):
    image = Image.open(image_name)
    # fake batch dimension required to fit network's input dimensions
    image = loader(image).unsqueeze(0)
    return image.to(device, torch.float)
